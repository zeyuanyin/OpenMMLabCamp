# %% [markdown]
# # 安装配置MMagic

# %% [markdown]
# 按照顺序逐行运行本代码，即可安装配置 MMCV、MMagic环境
#
# 推荐代码运行[云GPU环境](https://featurize.cn?s=d7ce99f842414bfcaea5662a97581bd1)：GPU RTX 3060、CUDA v11.2
#
# 作者：同济子豪兄 2023-6-13

# %% [markdown]
# > 提示：以下代码运行时，若长时间运行卡着不动，可重启 kernel 后重新运行一遍

# %% [markdown]
# ## 安装Pytorch

# %%
# !pip install ipykernel
# Out:
# Running cells with '/home/zeyuan.yin/.conda/envs/mm/bin/python3.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /home/zeyuan.yin/.conda/envs/mm ipykernel --update-deps --force-reinstall'

# %%
# 安装Pytorch
# !pip3 install install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio==0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Running cells with '/home/zeyuan.yin/.conda/envs/mm/bin/python3.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /home/zeyuan.yin/.conda/envs/mm ipykernel --update-deps --force-reinstall'

# %% [markdown]
# ## 安装MMCV和MMEngine环境

# %%
# !pip3 install openmim
# !mim install 'mmcv>=2.0.0'
# !mim install 'mmengine'
# Out:
# Requirement already satisfied: openmim in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (0.3.7)
# Requirement already satisfied: Click in /home/zeyuan.yin/.local/lib/python3.8/site-packages (from openmim) (8.1.3)
# Requirement already satisfied: colorama in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from openmim) (0.1.11)
# Requirement already satisfied: pandas in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from openmim) (2.0.0)
# Requirement already satisfied: pip>=19.3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from openmim) (23.1.2)
# Requirement already satisfied: requests in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from model-index->openmim) (3.3.7)
# Requirement already satisfied: ordered-set in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->openmim) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->openmim) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->openmim) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->openmim) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->openmim) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->openmim) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->openmim) (2.15.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->openmim) (4.4.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from markdown->model-index->openmim) (6.6.0)
# Requirement already satisfied: zipp>=0.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.11.0)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.10.0/index.html
# Requirement already satisfied: mmcv>=2.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (2.0.0)
# Requirement already satisfied: addict in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0) (0.7.4)
# Requirement already satisfied: numpy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0) (1.24.3)
# Requirement already satisfied: packaging in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0) (23.0)
# Requirement already satisfied: Pillow in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0) (9.5.0)
# Requirement already satisfied: pyyaml in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0) (6.0)
# Requirement already satisfied: yapf in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0) (0.40.0)
# Requirement already satisfied: opencv-python>=3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0) (4.7.0.72)
# Requirement already satisfied: matplotlib in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine>=0.2.0->mmcv>=2.0.0) (3.7.1)
# Requirement already satisfied: rich in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine>=0.2.0->mmcv>=2.0.0) (13.4.2)
# Requirement already satisfied: termcolor in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine>=0.2.0->mmcv>=2.0.0) (2.2.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from yapf->mmcv>=2.0.0) (6.6.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from yapf->mmcv>=2.0.0) (3.5.3)
# Requirement already satisfied: tomli>=2.0.1 in /home/zeyuan.yin/.local/lib/python3.8/site-packages (from yapf->mmcv>=2.0.0) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv>=2.0.0) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0) (5.12.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0) (2.15.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0) (4.4.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.2.0->mmcv>=2.0.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv>=2.0.0) (1.16.0)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.10.0/index.html
# Requirement already satisfied: mmengine in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (0.7.4)
# Requirement already satisfied: addict in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine) (2.4.0)
# Requirement already satisfied: matplotlib in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine) (3.7.1)
# Requirement already satisfied: numpy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine) (1.24.3)
# Requirement already satisfied: pyyaml in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine) (6.0)
# Requirement already satisfied: rich in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine) (2.2.0)
# Requirement already satisfied: yapf in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine) (0.40.0)
# Requirement already satisfied: opencv-python>=3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine) (5.12.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine) (2.15.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine) (4.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from yapf->mmengine) (6.6.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from yapf->mmengine) (3.5.3)
# Requirement already satisfied: tomli>=2.0.1 in /home/zeyuan.yin/.local/lib/python3.8/site-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)

# %% [markdown]
# ## 安装MMagic

# %%
# !mim install 'mmagic'
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu117/torch2.0.0/index.html
# Collecting mmagic
#   Downloading mmagic-1.0.1-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.5 MB/s eta 0:00:00a 0:00:010m
# Collecting av (from mmagic)
#   Downloading av-10.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 23.1 MB/s eta 0:00:0000:0100:01
# Collecting controlnet-aux (from mmagic)
#   Downloading controlnet_aux-0.0.5-py3-none-any.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.0/231.0 kB 28.3 MB/s eta 0:00:00
# Collecting diffusers>=0.12.0 (from mmagic)
#   Downloading diffusers-0.17.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.0 MB/s eta 0:00:00
# Requirement already satisfied: einops in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic) (0.6.0)
# Collecting face-alignment (from mmagic)
#   Downloading face_alignment-1.4.0-py2.py3-none-any.whl (29 kB)
# Collecting facexlib (from mmagic)
#   Downloading facexlib-0.3.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 10.7 MB/s eta 0:00:00
# Collecting lmdb (from mmagic)
#   Downloading lmdb-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.9/298.9 kB 35.4 MB/s eta 0:00:00
# Collecting lpips (from mmagic)
#   Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 6.9 MB/s eta 0:00:00
# Collecting mediapipe (from mmagic)
#   Downloading mediapipe-0.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 23.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: mmcv>=2.0.0rc1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic) (2.0.0)
# Requirement already satisfied: mmengine in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic) (0.7.4)
# Requirement already satisfied: numpy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic) (1.24.3)
# Requirement already satisfied: opencv-python!=4.5.5.62,!=4.5.5.64 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic) (4.7.0.72)
# Requirement already satisfied: Pillow in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic) (9.5.0)
# Collecting resize-right (from mmagic)
#   Downloading resize_right-0.0.2-py3-none-any.whl (8.9 kB)
# Collecting tensorboard (from mmagic)
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 33.8 MB/s eta 0:00:0000:0100:01
# Collecting transformers>=4.27.4 (from mmagic)
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 31.4 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: filelock in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic) (3.10.7)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic) (0.13.3)
# Requirement already satisfied: importlib-metadata in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic) (6.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic) (2023.5.5)
# Requirement already satisfied: requests in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic) (2.28.2)
# Requirement already satisfied: addict in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0rc1->mmagic) (2.4.0)
# Requirement already satisfied: packaging in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0rc1->mmagic) (23.0)
# Requirement already satisfied: pyyaml in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0rc1->mmagic) (6.0)
# Requirement already satisfied: yapf in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv>=2.0.0rc1->mmagic) (0.40.0)
# Requirement already satisfied: matplotlib in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine->mmagic) (3.7.1)
# Requirement already satisfied: rich in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine->mmagic) (13.4.2)
# Requirement already satisfied: termcolor in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine->mmagic) (2.2.0)
# Collecting huggingface-hub>=0.13.2 (from diffusers>=0.12.0->mmagic)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.5 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=4.27.4->mmagic)
#   Downloading tokenizers-0.13.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 35.5 MB/s eta 0:00:0000:0100:01m
# Collecting safetensors>=0.3.1 (from transformers>=4.27.4->mmagic)
#   Downloading safetensors-0.3.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers>=4.27.4->mmagic) (4.65.0)
# Collecting scikit-image (from controlnet-aux->mmagic)
#   Using cached scikit_image-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.9 MB)
# Requirement already satisfied: scipy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from controlnet-aux->mmagic) (1.10.1)
# Requirement already satisfied: timm in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from controlnet-aux->mmagic) (0.6.13)
# Requirement already satisfied: torch in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from controlnet-aux->mmagic) (2.0.0)
# Requirement already satisfied: torchvision in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from controlnet-aux->mmagic) (0.15.1)
# Collecting numba (from face-alignment->mmagic)
#   Downloading numba-0.57.0-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 32.2 MB/s eta 0:00:00ta 0:00:01
# Collecting filterpy (from facexlib->mmagic)
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 28.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting absl-py (from mediapipe->mmagic)
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting attrs>=19.1.0 (from mediapipe->mmagic)
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 9.4 MB/s eta 0:00:00
# Collecting flatbuffers>=2.0 (from mediapipe->mmagic)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting opencv-contrib-python (from mediapipe->mmagic)
#   Downloading opencv_contrib_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 MB 16.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: protobuf<4,>=3.11 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mediapipe->mmagic) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe->mmagic)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: grpcio>=1.48.2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic) (1.53.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard->mmagic)
#   Downloading google_auth-2.20.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 27.7 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard->mmagic)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic) (67.8.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->mmagic)
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 31.5 MB/s eta 0:00:0000:0100:01
# Collecting werkzeug>=1.0.1 (from tensorboard->mmagic)
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.26 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic) (0.38.4)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard->mmagic)
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard->mmagic)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard->mmagic)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.9.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmagic) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmagic) (1.26.15)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard->mmagic)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting fsspec (from huggingface-hub>=0.13.2->diffusers>=0.12.0->mmagic)
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/zeyuan.yin/.local/lib/python3.8/site-packages (from huggingface-hub>=0.13.2->diffusers>=0.12.0->mmagic) (4.3.0)
# Requirement already satisfied: zipp>=0.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from importlib-metadata->diffusers>=0.12.0->mmagic) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->diffusers>=0.12.0->mmagic) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->diffusers>=0.12.0->mmagic) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->diffusers>=0.12.0->mmagic) (2023.5.7)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe->mmagic)
#   Downloading cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.7/442.7 kB 29.7 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (1.11.1)
# Requirement already satisfied: networkx in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (3.1)
# Requirement already satisfied: jinja2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from torch->controlnet-aux->mmagic) (2.0.0)
# Requirement already satisfied: cmake in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from triton==2.0.0->torch->controlnet-aux->mmagic) (3.26.1)
# Requirement already satisfied: lit in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from triton==2.0.0->torch->controlnet-aux->mmagic) (16.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard->mmagic) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine->mmagic) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine->mmagic) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine->mmagic) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine->mmagic) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine->mmagic) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine->mmagic) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmengine->mmagic) (5.12.0)
# Collecting llvmlite<0.41,>=0.40.0dev0 (from numba->face-alignment->mmagic)
#   Downloading llvmlite-0.40.1rc1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 21.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine->mmagic) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine->mmagic) (2.15.1)
# Collecting imageio>=2.27 (from scikit-image->controlnet-aux->mmagic)
#   Downloading imageio-2.31.1-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 36.7 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12 (from scikit-image->controlnet-aux->mmagic)
#   Using cached tifffile-2023.4.12-py3-none-any.whl (219 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image->controlnet-aux->mmagic)
#   Using cached PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Collecting lazy_loader>=0.2 (from scikit-image->controlnet-aux->mmagic)
#   Using cached lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from yapf->mmcv>=2.0.0rc1->mmagic) (3.5.3)
# Requirement already satisfied: tomli>=2.0.1 in /home/zeyuan.yin/.local/lib/python3.8/site-packages (from yapf->mmcv>=2.0.0rc1->mmagic) (2.0.1)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe->mmagic)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: mdurl~=0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->mmengine->mmagic) (0.1.2)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->mmagic)
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->mmagic)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from sympy->torch->controlnet-aux->mmagic) (1.3.0)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=e94a48f19996163a0e82abd03732e32a481820395e6144978cac125ebc274889
#   Stored in directory: /home/zeyuan.yin/.cache/pip/wheels/fe/f6/cb/40331472edf4fd399b8cad02973c6acbdf26898342928327fe
# Successfully built filterpy
# Installing collected packages: tokenizers, safetensors, resize-right, lmdb, flatbuffers, av, werkzeug, tifffile, tensorboard-data-server, PyWavelets, pycparser, pyasn1, opencv-contrib-python, oauthlib, llvmlite, lazy_loader, imageio, fsspec, cachetools, attrs, absl-py, scikit-image, rsa, requests-oauthlib, pyasn1-modules, numba, huggingface-hub, CFFI, transformers, sounddevice, google-auth, filterpy, diffusers, mediapipe, google-auth-oauthlib, tensorboard, lpips, facexlib, face-alignment, controlnet-aux, mmagic
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.3.0
#     Uninstalling safetensors-0.3.0:
#       Successfully uninstalled safetensors-0.3.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.13.3
#     Uninstalling huggingface-hub-0.13.3:
#       Successfully uninstalled huggingface-hub-0.13.3
# Successfully installed CFFI-1.15.1 PyWavelets-1.4.1 absl-py-1.4.0 attrs-23.1.0 av-10.0.0 cachetools-5.3.1 controlnet-aux-0.0.5 diffusers-0.17.1 face-alignment-1.4.0 facexlib-0.3.0 filterpy-1.4.5 flatbuffers-23.5.26 fsspec-2023.6.0 google-auth-2.20.0 google-auth-oauthlib-1.0.0 huggingface-hub-0.15.1 imageio-2.31.1 lazy_loader-0.2 llvmlite-0.40.1rc1 lmdb-1.4.1 lpips-0.1.4 mediapipe-0.10.1 mmagic-1.0.1 numba-0.57.0 oauthlib-3.2.2 opencv-contrib-python-4.7.0.72 pyasn1-0.5.0 pyasn1-modules-0.3.0 pycparser-2.21 requests-oauthlib-1.3.1 resize-right-0.0.2 rsa-4.9 safetensors-0.3.1 scikit-image-0.21.0 sounddevice-0.4.6 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tifffile-2023.4.12 tokenizers-0.13.3 transformers-4.30.2 werkzeug-2.3.6

# %% [markdown]
# ## 从源码安装MMagic

# %%
# !rm -rf mmagic # 删除原有的 mmagic 文件夹（如有）

# !git clone https://github.com/open-mmlab/mmagic.git # 下载 mmagic 源代码
# Out:
# Cloning into 'mmagic'...
# remote: Enumerating objects: 25648, done.
# remote: Counting objects: 100% (3612/3612), done.
# remote: Compressing objects: 100% (1596/1596), done.
# remote: Total 25648 (delta 2017), reused 3426 (delta 1963), pack-reused 22036
# Receiving objects: 100% (25648/25648), 21.61 MiB | 6.15 MiB/s, done.
# Resolving deltas: 100% (17127/17127), done.
# Updating files: 100% (1535/1535), done.

# %%
import os
os.chdir('mmagic')

# %%
# !pip3 install -e .
# Out:
# Obtaining file:///home/zeyuan.yin/OpenMMLabCamp/homework-5/code/mmagic/mmagic
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: av in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (10.0.0)
# Requirement already satisfied: click in /home/zeyuan.yin/.local/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (8.1.3)
# Requirement already satisfied: controlnet_aux in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (0.0.5)
# Requirement already satisfied: diffusers>=0.12.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (0.14.0)
# Requirement already satisfied: einops in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (0.6.0)
# Requirement already satisfied: face-alignment<=1.3.4 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (1.3.4)
# Requirement already satisfied: facexlib in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (0.3.0)
# Requirement already satisfied: lmdb in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (1.4.1)
# Requirement already satisfied: lpips in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (0.1.4)
# Requirement already satisfied: mediapipe in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (0.10.1)
# Requirement already satisfied: numpy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (1.24.3)
# Requirement already satisfied: opencv-python!=4.5.5.62,!=4.5.5.64 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (4.7.0.72)
# Requirement already satisfied: pandas in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (2.0.0)
# Requirement already satisfied: Pillow in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (9.5.0)
# Requirement already satisfied: resize_right in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (0.0.2)
# Requirement already satisfied: tensorboard in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (2.13.0)
# Requirement already satisfied: transformers>=4.27.4 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmagic==1.0.2.dev0) (4.30.2)
# Requirement already satisfied: importlib-metadata in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic==1.0.2.dev0) (6.6.0)
# Requirement already satisfied: filelock in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic==1.0.2.dev0) (3.10.7)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic==1.0.2.dev0) (0.15.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic==1.0.2.dev0) (2023.5.5)
# Requirement already satisfied: requests in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers>=0.12.0->mmagic==1.0.2.dev0) (2.28.2)
# Requirement already satisfied: torch in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from face-alignment<=1.3.4->mmagic==1.0.2.dev0) (1.10.1+cu113)
# Requirement already satisfied: scipy>=0.17 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from face-alignment<=1.3.4->mmagic==1.0.2.dev0) (1.10.1)
# Requirement already satisfied: scikit-image in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from face-alignment<=1.3.4->mmagic==1.0.2.dev0) (0.21.0)
# Requirement already satisfied: tqdm in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from face-alignment<=1.3.4->mmagic==1.0.2.dev0) (4.65.0)
# Requirement already satisfied: numba in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from face-alignment<=1.3.4->mmagic==1.0.2.dev0) (0.57.0)
# Requirement already satisfied: packaging>=20.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers>=4.27.4->mmagic==1.0.2.dev0) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers>=4.27.4->mmagic==1.0.2.dev0) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers>=4.27.4->mmagic==1.0.2.dev0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers>=4.27.4->mmagic==1.0.2.dev0) (0.3.1)
# Requirement already satisfied: timm in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from controlnet_aux->mmagic==1.0.2.dev0) (0.6.13)
# Requirement already satisfied: torchvision in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from controlnet_aux->mmagic==1.0.2.dev0) (0.11.2+cu113)
# Requirement already satisfied: filterpy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from facexlib->mmagic==1.0.2.dev0) (1.4.5)
# Requirement already satisfied: absl-py in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mediapipe->mmagic==1.0.2.dev0) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mediapipe->mmagic==1.0.2.dev0) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mediapipe->mmagic==1.0.2.dev0) (23.5.26)
# Requirement already satisfied: matplotlib in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mediapipe->mmagic==1.0.2.dev0) (3.7.1)
# Requirement already satisfied: opencv-contrib-python in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mediapipe->mmagic==1.0.2.dev0) (4.7.0.72)
# Requirement already satisfied: protobuf<4,>=3.11 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mediapipe->mmagic==1.0.2.dev0) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mediapipe->mmagic==1.0.2.dev0) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->mmagic==1.0.2.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->mmagic==1.0.2.dev0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->mmagic==1.0.2.dev0) (2023.3)
# Requirement already satisfied: grpcio>=1.48.2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic==1.0.2.dev0) (1.53.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic==1.0.2.dev0) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic==1.0.2.dev0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic==1.0.2.dev0) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic==1.0.2.dev0) (67.8.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic==1.0.2.dev0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic==1.0.2.dev0) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from tensorboard->mmagic==1.0.2.dev0) (0.38.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmagic==1.0.2.dev0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmagic==1.0.2.dev0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmagic==1.0.2.dev0) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmagic==1.0.2.dev0) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmagic==1.0.2.dev0) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->mmagic==1.0.2.dev0) (1.3.1)
# Requirement already satisfied: fsspec in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from huggingface-hub>=0.10.0->diffusers>=0.12.0->mmagic==1.0.2.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from huggingface-hub>=0.10.0->diffusers>=0.12.0->mmagic==1.0.2.dev0) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from importlib-metadata->diffusers>=0.12.0->mmagic==1.0.2.dev0) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->diffusers>=0.12.0->mmagic==1.0.2.dev0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->diffusers>=0.12.0->mmagic==1.0.2.dev0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->diffusers>=0.12.0->mmagic==1.0.2.dev0) (2023.5.7)
# Requirement already satisfied: CFFI>=1.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from sounddevice>=0.4.4->mediapipe->mmagic==1.0.2.dev0) (1.15.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard->mmagic==1.0.2.dev0) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mediapipe->mmagic==1.0.2.dev0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mediapipe->mmagic==1.0.2.dev0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mediapipe->mmagic==1.0.2.dev0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mediapipe->mmagic==1.0.2.dev0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mediapipe->mmagic==1.0.2.dev0) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mediapipe->mmagic==1.0.2.dev0) (5.12.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from numba->face-alignment<=1.3.4->mmagic==1.0.2.dev0) (0.40.1rc1)
# Requirement already satisfied: networkx>=2.8 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from scikit-image->face-alignment<=1.3.4->mmagic==1.0.2.dev0) (3.1)
# Requirement already satisfied: imageio>=2.27 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from scikit-image->face-alignment<=1.3.4->mmagic==1.0.2.dev0) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from scikit-image->face-alignment<=1.3.4->mmagic==1.0.2.dev0) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from scikit-image->face-alignment<=1.3.4->mmagic==1.0.2.dev0) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from scikit-image->face-alignment<=1.3.4->mmagic==1.0.2.dev0) (0.2)
# Requirement already satisfied: pycparser in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe->mmagic==1.0.2.dev0) (2.21)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->mmagic==1.0.2.dev0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->mmagic==1.0.2.dev0) (3.2.2)
# Installing collected packages: mmagic
#   Attempting uninstall: mmagic
#     Found existing installation: mmagic 1.0.2.dev0
#     Uninstalling mmagic-1.0.2.dev0:
#       Successfully uninstalled mmagic-1.0.2.dev0
#   Running setup.py develop for mmagic
# Successfully installed mmagic

# %% [markdown]
# ## 检查安装成功

# %%
# 检查 Pytorch
import torch, torchvision
print('Pytorch 版本', torch.__version__)
print('CUDA 是否可用',torch.cuda.is_available())
# Out:
# Pytorch 版本 2.0.1+cu117
# CUDA 是否可用 True

# %%
# 检查 mmcv
import mmcv
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print('MMCV版本', mmcv.__version__)
print('CUDA版本', get_compiling_cuda_version())
print('编译器版本', get_compiler_version())
# Out:
# MMCV版本 2.0.0
# CUDA版本 11.7
# 编译器版本 GCC 9.3

# %%
# 检查 mmagic
import mmagic
print('MMagic版本', mmagic.__version__)
# Out:
# MMagic版本 1.0.2dev0

# %% [markdown]
# 没有报错，即证明安装成功。

# %% [markdown]
# ## 安装其它工具包

# %%
# !pip install opencv-python pillow matplotlib seaborn tqdm -i https://pypi.tuna.tsinghua.edu.cn/simple
# !pip install clip transformers gradio 'httpx[socks]' diffusers==0.14.0 -i https://pypi.tuna.tsinghua.edu.cn/simple
# !mim install 'mmdet>=3.0.0'
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: opencv-python in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (4.7.0.72)
# Requirement already satisfied: pillow in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (9.5.0)
# Requirement already satisfied: matplotlib in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (3.7.1)
# Requirement already satisfied: seaborn in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: tqdm in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (4.65.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: pandas>=0.25 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: clip in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: transformers in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (4.30.2)
# Requirement already satisfied: gradio in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (3.35.2)
# Requirement already satisfied: httpx[socks] in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (0.24.1)
# Requirement already satisfied: diffusers==0.14.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (0.14.0)
# Requirement already satisfied: importlib-metadata in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers==0.14.0) (6.6.0)
# Requirement already satisfied: filelock in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers==0.14.0) (3.10.7)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers==0.14.0) (0.15.1)
# Requirement already satisfied: numpy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers==0.14.0) (1.24.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers==0.14.0) (2023.5.5)
# Requirement already satisfied: requests in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers==0.14.0) (2.28.2)
# Requirement already satisfied: Pillow in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from diffusers==0.14.0) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: aiofiles in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: aiohttp in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: altair>=4.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (5.0.1)
# Requirement already satisfied: fastapi in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (0.97.0)
# Requirement already satisfied: ffmpy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: gradio-client>=0.2.7 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (0.2.7)
# Requirement already satisfied: jinja2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: markupsafe in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (2.1.2)
# Requirement already satisfied: matplotlib in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: orjson in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (3.9.1)
# Requirement already satisfied: pandas in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (2.0.0)
# Requirement already satisfied: pydantic in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (1.10.9)
# Requirement already satisfied: pydub in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: pygments>=2.12.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (2.15.1)
# Requirement already satisfied: python-multipart in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: semantic-version in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (0.22.0)
# Requirement already satisfied: websockets>=10.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio) (11.0.3)
# Requirement already satisfied: certifi in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from httpx[socks]) (2023.5.7)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from httpx[socks]) (0.17.2)
# Requirement already satisfied: idna in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from httpx[socks]) (3.4)
# Requirement already satisfied: sniffio in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from httpx[socks]) (1.3.0)
# Requirement already satisfied: socksio==1.* in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from httpx[socks]) (1.0.0)
# Requirement already satisfied: jsonschema>=3.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from altair>=4.2.0->gradio) (4.4.0)
# Requirement already satisfied: fsspec in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from gradio-client>=0.2.7->gradio) (2023.6.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from httpcore<0.18.0,>=0.15.0->httpx[socks]) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from httpcore<0.18.0,>=0.15.0->httpx[socks]) (3.7.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->gradio) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from pandas->gradio) (2023.3)
# Requirement already satisfied: click>=7.0 in /home/zeyuan.yin/.local/lib/python3.8/site-packages (from uvicorn>=0.14.0->gradio) (8.1.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from aiohttp->gradio) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from aiohttp->gradio) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from aiohttp->gradio) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: zipp>=0.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from importlib-metadata->diffusers==0.14.0) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->gradio) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->gradio) (5.12.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from requests->diffusers==0.14.0) (1.26.15)
# Requirement already satisfied: exceptiongroup in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx[socks]) (1.1.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.2)
# Requirement already satisfied: six>=1.5 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->gradio) (1.16.0)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.10.0/index.html
# Requirement already satisfied: mmdet>=3.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: matplotlib in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (3.7.1)
# Requirement already satisfied: numpy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (1.24.3)
# Requirement already satisfied: pycocotools in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (2.0.6)
# Requirement already satisfied: scipy in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (1.10.1)
# Requirement already satisfied: shapely in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (2.0.1)
# Requirement already satisfied: six in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (1.16.0)
# Requirement already satisfied: terminaltables in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (3.1.10)
# Requirement already satisfied: mmcv<2.1.0,>=2.0.0rc4 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (2.0.0)
# Requirement already satisfied: mmengine<1.0.0,>=0.7.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmdet>=3.0.0) (0.7.4)
# Requirement already satisfied: addict in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (2.4.0)
# Requirement already satisfied: packaging in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (23.0)
# Requirement already satisfied: Pillow in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (9.5.0)
# Requirement already satisfied: pyyaml in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (6.0)
# Requirement already satisfied: yapf in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (0.40.0)
# Requirement already satisfied: opencv-python>=3 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (4.7.0.72)
# Requirement already satisfied: rich in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0) (13.4.2)
# Requirement already satisfied: termcolor in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmdet>=3.0.0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmdet>=3.0.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmdet>=3.0.0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmdet>=3.0.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmdet>=3.0.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmdet>=3.0.0) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from matplotlib->mmdet>=3.0.0) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->mmdet>=3.0.0) (3.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0) (2.15.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0) (4.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from yapf->mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (6.6.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from yapf->mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (3.5.3)
# Requirement already satisfied: tomli>=2.0.1 in /home/zeyuan.yin/.local/lib/python3.8/site-packages (from yapf->mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0) (2.0.1)
# Requirement already satisfied: mdurl~=0.1 in /home/zeyuan.yin/.conda/envs/torch/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0) (0.1.2)

# %%
import lpips
